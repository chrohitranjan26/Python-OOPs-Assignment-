# %% [markdown]
# # Theoretical Questions

# %% [markdown]
# Q1.  What is Object-Oriented Programming (OOP) ?
#
# Ans: Object-Oriented Programming (OOP) is a way of writing code in which we need to create objects that contain data and methods to work with that data together in one place, just like real life. Objects represent real-world entities and contain both data (attributes) and behavior (methods).
#
# Q2. What is a class in OOP ?
#
# Ans:  The class is a user-defined data structure that combines the methods and data members into a single entity and it is a blueprint or template used to create objects.
#
# Q3.  What is an object in OOP ?
#
# Ans: Object is an instance of a class and it consists of a set of methods and attributes. Actions are carried out using a class's object. Objects have two qualities: They exhibit states and actions. (The object is equipped with properties and methods) Methods represent its behaviour, while attributes represent its state. If class is a blueprint, an object is the actual item made from it.
#
# Q4. What is the difference between abstraction and encapsulation ?
#
# Ans:  Abstraction is the concept of Object-Oriented Programming (OOP) in which it shows only important features and hides internal details and Hides complex implementation and Achieved using abstract classes / interfaces whereas Encapsulation is also the concept of Object-Oriented Programming (OOP) in which it wraps data and methods together and protects the data, Binds data and methods together, Focuses on how data is protected and Achieved using classes & access control.
#
# Q5. What are dunder methods in Python ?
#
# Ans: Dunder methods are special methods in Python that start and end with double underscores (__method__) and it allows custom objects to use built-in operations and operators.
#
# Q6. Explain the concept of Inheritance in OOP .
#
# Ans: Inheritance is an important concept of OOPs method where a child class acquires properties and methods of a parent class and it means one class (child) can use the properties and methods of another class (parent).
#
# Q7. What is polymorphism in OOP ?
#
# Ans: Polymorphism is an OOP concept where the same method performs different actions depending on the object and for different objects and gets different output depending on the object.
#
# Q8. How is encapsulation achieved in Python ?
#
# Ans: encapsulation is achieved by grouping data (variables) and methods (functions) into a single unit called a class, and together inside a class and controlling access to that data and also by using access modifiers to restrict direct access to certain components.
#
# Q9. What is a constructor in Python ?
#
# Ans: constructor is a special method used to initialize a new object when it is created. It is defined using the name (__init__ ). When we create an object, Python runs this method to assign initial values to the object’s variables.
#
# Q10.  What are class and static methods in Python ?
#
# Ans: A class method is a method that works with the class itself, not with individual objects. It uses the decorator (@classmethod) and takes (cls) as its first parameter, which represents the class. Class methods are commonly used to access or modify class-level data whereas static method is a method that does not depend on the class or object data. It uses the decorator (@staticmethod) and does not take (self or cls) as a parameter. Static methods are used when the method logically belongs to a class but does not need to access class or instance variables.
#
# Q11. What is method overloading in Python ?
#
# Ans: Overloading Method means having multiple methods with the same name but different parameters. However, Python does not support method overloading in the traditional way. If we want to define multiple methods with the same name in a class, Python will simply forget the first one and only use the last one. We can use overloading method by using Using default arguments (we can set a parameter to None or a default value)  and Using variable-length arguments (*args, **kwargs).
#
# Q12. What is method overriding in OOP ?
#
# Ans: Method overriding means a child class changes the behavior of a method that it inherited from its parent class or we can say redefining  behavior of a method of child class. The overridden method in the child class has the same name and parameters as the parent’s method but provides a different implementation. This allows the child class to change the behavior of the parent class method.
#
# Q13. What is a property decorator in Python ?
#
# Ans: The property decorator (@property) is a built-in tool that accesses methods like they are regular attributes. It is mainly used to look, add, or delete private variables safely without directly accessing them. we can control how a variable is read or changed while still using simple syntax like (object.variable). This makes the code cleaner and helps protect the data inside a class.
#
# Q14.  Why is polymorphism important in OOP ?
#
# Ans: Polymorphism is important in OOP because it allows different objects to be treated in a similar way even if they behave differently. We  can write one function or method that works with different types of objects and It makes programs scalable, because you can add new classes without changing existing code.
#
# Q15. What is an abstract class in Python ?
#
# Ans: An abstract class is a class that cannot be used to create objects directly. It provide a blueprint for other classes. Abstract classes can have abstract methods, which are methods declared but not implemented. Any class that inherits from an abstract class must implement all its abstract methods, otherwise it cannot be instantiated.  its only purpose is to define a set of rules (methods) that its subclass must follow.
#
# Q16. What are the advantages of OOP ?
#
# Ans: The advantages of Object-Oriented Programming (OOP) are as follows:
# Modularity – Code is organized into classes, so it’s easier to manage.
# Reusability – You can reuse existing classes in new programs through inheritance.
# Encapsulation – Data is hidden inside classes and accessed only through methods, which protects it from accidental changes.
# Polymorphism – Different objects can be used interchangeably, allowing flexible and scalable code.
# Abstraction – Complex details are hidden, and you can focus on what an object does, not how it does it.
# Maintainability – Organized structure and modular code make updating and modifying programs easier.
# Real-world modeling – OOP makes it easier to represent real-world entities like cars, animals, or employees in programs.
#
# Q17. What is the difference between a class variable and an instance variable ?
#
# Ans: A class variable is data that is shared by every single object created from that class. It is defined outside the constructor, directly under the class name, and it belongs to the class, not a specific object, Only one copy exists, shared by all object, Can be accessed using class name or object and Used for common properties of all objects. Whereas
#
# An instance variable is data that is unique to each individual object created from a class. These are defined inside the constructor (__init__) using the self keyword. It Belongs to the object/instance, Separate copy for each object, Can be accessed only through the object and Used for individual properties of an object.
#
# Q18.  What is multiple inheritance in Python ?
#
# Ans: Multiple inheritance in Python is when a class can inherit from more than one parent class. This means the child class can access attributes and methods from all its parent classes, allowing for more flexible and reusable code.
#
# Q19.  Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python .
#
# Ans: The ( __str__ ) method is used to provide a user-friendly, readable representation of an object. The purpose is to make the output understandable and meaningful to end users. This makes it useful whenever you want to show the object in a human-readable form.
#
# The (__repr__) method is used to provide a detailed, unambiguous version of the object for developers. It is used for debugging and logging. This method helps in understanding the object’s structure and contents more precisely, which is useful during program development and debugging.
#
# Q20. What is the significance of the ‘super()’ function in Python ?
#
# Ans: The function is used to call methods from a parent class inside a child (subclass). It allows the child class to reuse or extend the functionality of the parent class without explicitly naming it. This is especially useful in inheritance, including multiple inheritance, because it ensures that the parent class methods are called in a safe and consistent way .
#
# Q21. What is the significance of the __del__ method in Python ?
#
# Ans:  This method is known as the Destructor.  It is automatically invoked when an object is about to be destroyed or removed from memory. Its main purpose is to perform cleanup tasks, such as closing files, releasing resources, or freeing memory, before the object is deleted.
#
# Q22. What is the difference between @staticmethod and @classmethod in Python ?
#
# Ans: A static method (@staticmethod) is a method that does not depend on the class or object. It cannot access instance variables or class variables. It is just a function that is part of the class for organizational purposes. You call it using the class name or an object. it is utility methods, independent of class or object. Whereas
#
# A class method (@classmethod) is a method that works with the class itself, not individual objects. It takes class variables as the first parameter, which refers to the class. It can access or modify class variables and is often used for alternative constructors or methods that affect the whole class. Methods that work with class data or alternative constructors
#
# Q23. How does polymorphism work in Python with inheritance ?
#
# Ans: Polymorphism with inheritance works by allowing a child class to provide its own version of a method defined in the parent class, and then calling that method on objects of different classes in the same way. This is called method overriding and is a core part of runtime polymorphism. Python decides which method to execute based on the type of object at runtime, not the type of reference.
#
# Q24. What is method chaining in Python OOP ?
#
# Ans: Method chaining is a technique in OOP where we can call multiple methods on the same object in a single line of code, linked together by dots. Instead of performing an action, saving the result, and then performing the next action, we "chain" them together like a series of connected links. This makes code more concise, readable, and fluent, especially when performing multiple operations on the same object.
#
# Q25.  What is the purpose of the __call__ method in Python?
#
# Ans: ( __call__) it is a special method in python that allows an object of a class to be called like a function. When we define ( __call__ ) in a class, with parentheses on an object to execute the code inside that method. This is useful when we want objects to behave like functions while still keeping their state and other methods.

# %% [markdown]
# #Practical Questions

# %%
'''Q1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!". '''

class Animal:
    def speak(self):
        print("This animal makes a sound")


class Dog(Animal):
    def speak(self):
        print("Bark!")


animal = Animal()
animal.speak()

dog = Dog()
dog.speak()
# Out:
# This animal makes a sound
# Bark!

# %%
"Q2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both."

from abc import ABC, abstractmethod
import math


class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


c = Circle(5)
r = Rectangle(4, 6)

print(f"Area of Circle: {c.area():.2f}")
print(f"Area of Rectangle: {r.area()}")
# Out:
# Area of Circle: 78.54
# Area of Rectangle: 24

# %%
"Q3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute."

class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def show_type(self):
        print(f"Vehicle type: {self.type}")


class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_brand(self):
        print(f"Car brand: {self.brand}")


class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery):
        super().__init__(vehicle_type, brand)
        self.battery = battery

    def show_battery(self):
        print(f"Battery capacity: {self.battery} kWh")


ecar = ElectricCar("Car", "Tesla", 100)
ecar.show_type()
ecar.show_brand()
ecar.show_battery()
# Out:
# Vehicle type: Car
# Car brand: Tesla
# Battery capacity: 100 kWh

# %%
"Q4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method."

class Bird:
    def fly(self):
        print("Some birds can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly high!")


class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly, it swims instead!")


birds = [Sparrow(), Penguin(), Bird()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow can fly high!
# Penguin cannot fly, it swims instead!
# Some birds can fly

# %%
"Q5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance."

class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance


    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Deposit amount must be positive")


    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance or invalid amount")


    def check_balance(self):
        print(f"Current balance: {self.__balance}")



account = BankAccount(1000)
account.check_balance()

account.deposit(500)
account.check_balance()

account.withdraw(200)
account.check_balance()
# Out:
# Current balance: 1000
# Deposited: 500
# Current balance: 1500
# Withdrawn: 200
# Current balance: 1300

# %%
"Q6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play()"

class Instrument:
    def play(self):
        print("Some instrument is playing")


class Guitar(Instrument):
    def play(self):
        print("Guitar is strumming chords")


class Piano(Instrument):
    def play(self):
        print("Piano is playing melody")


instruments = [Guitar(), Piano(), Instrument()]

for instrument in instruments:
    instrument.play()
# Out:
# Guitar is strumming chords
# Piano is playing melody
# Some instrument is playing

# %%
"Q7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers"

class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
       return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print("Addition using class method:", MathOperations.add_numbers(10, 5))
print("Subtraction using static method:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition using class method: 15
# Subtraction using static method: 5

# %%
"Q8. Implement a class Person with a class method to count the total number of persons created."

class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):

        return cls.count


p1 = Person("Rohit")
p2 = Person("Ranjan")
p3 = Person("putu")


print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %%
"Q9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as numerator/denominator"

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

print(f1)
print(f2)
# Out:
# 3/4
# 5/6

# %%
"Q10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors"

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y


    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)


    def __str__(self):
        return f"({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2
print(v3)
# Out:
# (6, 8)

# %%
"Q11. Create a class Person with attributes name and age. Add a method greet() that prints Hello, my name is {name} and I am {age} years old"

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age


    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


p1 = Person("Rohit", 25)

p1.greet()
# Out:
# Hello, my name is Rohit and I am 25 years old.

# %%
"Q12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades."

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades


    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)


s1 = Student("Rohit", [85, 90, 78, 92])
s2 = Student("shailesh", [70, 88, 95])
s3 = Student("sameer", [60, 80, 90])

print(f"{s1.name}'s average grade: {s1.average_grade():.2f}")
print(f"{s2.name}'s average grade: {s2.average_grade():.2f}")
print(f"{s3.name}'s average grade: {s3.average_grade():.2f}")
# Out:
# Rohit's average grade: 86.25
# shailesh's average grade: 84.33
# sameer's average grade: 76.67

# %%
"Q13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area"

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0


    def set_dimensions(self, length, width):
        self.length = length
        self.width = width


    def area(self):
        return self.length * self.width


rect = Rectangle()
rect.set_dimensions(5, 10)
print(f"Area of the rectangle: {rect.area()}")
# Out:
# Area of the rectangle: 50

# %%
"Q14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary"

class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate


    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus


    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


emp = Employee("Rohit", 40, 50000)
mgr = Manager("Ankit", 40, 500, 5000)

print(f"{emp.name}'s salary: {emp.calculate_salary()}")
print(f"{mgr.name}'s salary: {mgr.calculate_salary()}")
# Out:
# Rohit's salary: 2000000
# Ankit's salary: 25000

# %%
"Q15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product."

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity


    def total_price(self):
        return self.price * self.quantity


p1 = Product("watch", 50000, 2)
p2 = Product("shoes", 500, 5)

print(f"Total price of {p1.name}: {p1.total_price()}")
print(f"Total price of {p2.name}: {p2.total_price()}")
# Out:
# Total price of watch: 100000
# Total price of shoes: 2500

# %%
"Q16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method."


from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        print("Moo")


class Sheep(Animal):
    def sound(self):
        print("Baa")


cow = Cow()
sheep = Sheep()

cow.sound()
sheep.sound()
# Out:
# Moo
# Baa

# %%
"Q17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details."

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published


    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"


b1 = Book("1984", "George Orwell", 1949)
b2 = Book("To Kill a Mockingbird", "Harper Lee", 1960)

print(b1.get_book_info())
print(b2.get_book_info())
# Out:
# Title: 1984, Author: George Orwell, Year Published: 1949
# Title: To Kill a Mockingbird, Author: Harper Lee, Year Published: 1960

# %%
"Q18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms."

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def show_details(self):
        print(f"Address: {self.address}, Price: {self.price}")


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def show_details(self):

        print(f"Address: {self.address}, Price: {self.price}, Rooms: {self.number_of_rooms}")


house = House("123 Maple Street", 500000)
mansion = Mansion("456 Oak Avenue", 2000000, 10)

house.show_details()
mansion.show_details()
# Out:
# Address: 123 Maple Street, Price: 500000
# Address: 456 Oak Avenue, Price: 2000000, Rooms: 10
